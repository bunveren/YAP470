# %%
import os
import sys
import time
import joblib
import numpy as np
import cv2
from tqdm import tqdm
import warnings
warnings.filterwarnings('ignore')

from skimage.feature import local_binary_pattern, hog
from sklearn.model_selection import train_test_split, GridSearchCV, StratifiedKFold, RandomizedSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
import lightgbm as lgb
from sklearn.base import ClassifierMixin
from sklearn.feature_selection import SelectKBest, f_classif, RFE
from sklearn.linear_model import LogisticRegression  
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score
from sklearn.decomposition import PCA

 
def is_dfire_image_fire(annotation_path, fire_class_ids):
    if not os.path.exists(annotation_path): return False
    try:
        with open(annotation_path, 'r') as f:
            for line in f:
                parts = line.strip().split()
                if parts and len(parts) > 0:
                    if parts[0].isdigit():
                        class_id = int(parts[0])
                        if class_id in fire_class_ids: return True
    except Exception as e: pass
    return False

def extract_color_histograms(img_processed, color_space, bins):
    histograms = []
    ranges = {
        'hsv': {'float': ([0, 1], [0, 1], [0, 1]), 'uint8': ([0, 180], [0, 256], [0, 256])},
        'ycbcr': {'float': ([0, 1], [-0.5, 0.5], [-0.5, 0.5]), 'uint8': ([0, 256], [0, 256], [0, 256])}
    }
    channel_indices = {'hsv': [0, 1], 'ycbcr': [1, 2]} 
    dtype_key = 'float' if img_processed.dtype in [np.float32, np.float64] else 'uint8'

    if color_space in ranges and color_space in channel_indices:
        for i in channel_indices[color_space]:
            current_range = ranges[color_space][dtype_key][i]
            if img_processed.dtype != np.float32 and img_processed.dtype != np.uint8:
                 img_processed = img_processed.astype(np.float32)
                 dtype_key = 'float'
                 current_range = ranges[color_space][dtype_key][i]

            hist = cv2.calcHist([img_processed], [i], None, [bins], current_range)
            histograms.append(hist.flatten())

    if histograms: return np.concatenate(histograms)
    else: return np.array([])

def extract_lbp_features(img_gray, radius, n_points, method):
    
    if img_gray is None or img_gray.size == 0: return np.array([])
    if n_points is None: n_points = 8 * radius
     
    if img_gray.dtype != np.uint8 and img_gray.dtype != np.float64:
         img_gray = img_gray.astype(np.float64)

    try:
        lbp_image = local_binary_pattern(img_gray, n_points, radius, method=method)
        if method == 'uniform' or method == 'nri_uniform':
            n_bins = int(n_points + 2)  
            hist_range = (0, n_bins)
        elif method == 'ror':
            n_bins = int(n_points / radius + 2)  
            hist_range = (0, n_bins)
        else:  
            n_bins = int(2**n_points)
            hist_range = (0, n_bins)
        lbp_hist, _ = np.histogram(lbp_image.ravel(), bins=n_bins, range=hist_range)
        lbp_hist = lbp_hist.astype(np.float32)
        if lbp_hist.sum() > 0: lbp_hist /= lbp_hist.sum()  
        return lbp_hist.flatten()

    except Exception as e:
         
        return np.array([])  

def extract_hog_features(img_gray, orientations, pixels_per_cell, cells_per_block, block_norm):
    if img_gray is None or img_gray.size == 0: return np.array([])
    if img_gray.dtype != np.uint8 and img_gray.dtype != np.float64:
         img_gray = img_gray.astype(np.float64)  
    img_h, img_w = img_gray.shape
    cell_h, cell_w = pixels_per_cell
    block_h, block_w = cells_per_block
    min_img_h = cell_h * block_h
    min_img_w = cell_w * block_w

    if img_h < min_img_h or img_w < min_img_w:
        return np.array([])
    try:
        hog_features = hog(img_gray, orientations=orientations,
                           pixels_per_cell=pixels_per_cell,
                           cells_per_block=cells_per_block,
                           block_norm=block_norm,
                           visualize=False, feature_vector=True)
        return hog_features.flatten()
    except Exception as e:
        return np.array([])  

def combine_features(img_dict, feature_params):
    all_features = []
    if 'hsv' in img_dict and img_dict['hsv'] is not None:
        hsv_hist = extract_color_histograms(img_dict['hsv'], 'hsv', bins=feature_params.get('hist_bins', 100))
        if hsv_hist.size > 0: all_features.append(hsv_hist)
    if 'ycbcr' in img_dict and img_dict['ycbcr'] is not None:
        ycbcr_hist = extract_color_histograms(img_dict['ycbcr'], 'ycbcr', bins=feature_params.get('hist_bins', 100))
        if ycbcr_hist.size > 0: all_features.append(ycbcr_hist)
    if 'gray' in img_dict and img_dict['gray'] is not None:
        img_gray_processed = img_dict['gray']

        lbp_features = extract_lbp_features(img_gray_processed,
                                            radius=feature_params.get('lbp_radius', 3),
                                            n_points=feature_params.get('lbp_n_points', None),
                                            method=feature_params.get('lbp_method', 'uniform'))
        if lbp_features.size > 0: all_features.append(lbp_features)

        hog_features = extract_hog_features(img_gray_processed,
                                           orientations=feature_params.get('hog_orientations', 9),
                                           pixels_per_cell=feature_params.get('hog_pixels_per_cell', (8, 8)),
                                           cells_per_block=feature_params.get('hog_cells_per_block', (2, 2)),
                                           block_norm=feature_params.get('hog_block_norm', 'L2-Hys'))
        if hog_features.size > 0: all_features.append(hog_features)

    if all_features:
         
        all_features = [f.astype(np.float32) for f in all_features]
        combined_vector = np.concatenate(all_features)
        return combined_vector
    else:
        return np.array([])  

def load_and_extract_features_memory_safe(config, feature_params):
    dataset_choice = config.get('dataset_choice', 'dfire')
    data_root = config.get('data_root')
    target_size = config.get('target_img_size')
    color_spaces_to_load = config.get('color_spaces_to_load', ['bgr', 'hsv', 'ycbcr'])
    normalize_pixels = config.get('normalize_pixels', 1)
    fire_class_ids = config.get('fire_class_ids', [])

    if not data_root or not target_size: return np.array([]), np.array([])

    image_label_pairs = []
    img_extensions = ['.jpg', '.jpeg', '.png']
    annotation_extension = '.txt'
    images_dir = os.path.join(data_root, 'images')
    labels_dir = os.path.join(data_root, 'labels')

    if not os.path.isdir(images_dir) or not os.path.isdir(labels_dir):
        print(f"Error: Images or Labels directory not found in {data_root}")
        return np.array([]), np.array([])

    all_image_files = [f for f in os.listdir(images_dir) if os.path.splitext(f)[1].lower() in img_extensions]

    if not all_image_files:
        print(f"No image files found in {images_dir}")
        return np.array([]), np.array([])

    print("Determining Labels...")
    for filename in tqdm(all_image_files, desc="Determining Labels", leave=False):
        image_name_without_ext = os.path.splitext(filename)[0]
        annotation_path = os.path.join(labels_dir, image_name_without_ext + annotation_extension)
        label = 1 if is_dfire_image_fire(annotation_path, fire_class_ids) else 0
        image_label_pairs.append((os.path.join(images_dir, filename), label))
    print("Label determination complete.")

    if not image_label_pairs:
        print("No images with labels found.")
        return np.array([]), np.array([])

    all_features_list = []
    all_labels_list = []
    total_images_processed = 0
    total_images_skipped_reading = 0
    total_images_skipped_feature = 0

    print("Loading images and extracting features...")
    for image_path, label in tqdm(image_label_pairs, desc="Memory-safe Feature Extraction", leave=False):
        img_bgr = cv2.imread(image_path)

        if img_bgr is None:
            total_images_skipped_reading += 1
            continue

        try:
            img_resized = cv2.resize(img_bgr, target_size, interpolation=cv2.INTER_LINEAR)
            img_dict_single = {}  
            img_processed_bgr = None
            if normalize_pixels:
                img_processed_bgr = img_resized.astype(np.float32) / 255.0 
                img_resized_uint8 = img_resized.astype(np.uint8)
                img_gray = cv2.cvtColor(img_resized_uint8, cv2.COLOR_BGR2GRAY).astype(np.float32) / 255.0  
                if 'hsv' in color_spaces_to_load:
                    img_dict_single['hsv'] = cv2.cvtColor(img_resized_uint8, cv2.COLOR_BGR2HSV).astype(np.float32) / np.array([180, 255, 255], dtype=np.float32)  
                if 'ycbcr' in color_spaces_to_load:
                    img_dict_single['ycbcr'] = cv2.cvtColor(img_resized_uint8, cv2.COLOR_BGR2YCrCb).astype(np.float32) / 255.0  
            else:  
                img_processed_bgr = img_resized.astype(np.uint8)
                img_gray = cv2.cvtColor(img_processed_bgr, cv2.COLOR_BGR2GRAY)
                if 'hsv' in color_spaces_to_load:
                    img_dict_single['hsv'] = cv2.cvtColor(img_processed_bgr, cv2.COLOR_BGR2HSV)
                if 'ycbcr' in color_spaces_to_load:
                    img_dict_single['ycbcr'] = cv2.cvtColor(img_processed_bgr, cv2.COLOR_BGR2YCrCb)

             
            img_dict_single['gray'] = img_gray  
            if 'bgr' in color_spaces_to_load:
                img_dict_single['bgr'] = img_processed_bgr

            features_single = combine_features(img_dict_single, feature_params)

            if features_single.size > 0:
                all_features_list.append(features_single)
                all_labels_list.append(label)
                total_images_processed += 1
            else:
                total_images_skipped_feature += 1  

        except Exception as e:  
            total_images_skipped_feature += 1  


    print("Feature extraction complete.")
    print(f"Total images initially found: {len(image_label_pairs)}")
    print(f"Images skipped (read error): {total_images_skipped_reading}")
    print(f"Images skipped (feature error): {total_images_skipped_feature}")
    print(f"Images successfully processed: {total_images_processed}")

    if not all_features_list:
        print("No features extracted from any image.")
        return np.array([]), np.array([])

    features_array = np.array(all_features_list, dtype=np.float32)  
    labels_array = np.array(all_labels_list, dtype=np.int32)

    print(f"Final features array shape: {features_array.shape}")
    print(f"Final labels array shape: {labels_array.shape}")

    return features_array, labels_array

def get_config(dataset_choice):
    config = {}
     
    if dataset_choice == 'kaggle':
        config['dataset_choice'] = 'kaggle'
        config['data_root'] = os.path.join('..', 'fire_dataset')  
        config['target_img_size'] = (128, 128)  
        config['color_spaces_to_load'] = ['bgr', 'hsv', 'ycbcr']  
        config['normalize_pixels'] = 1  
        config['fire_class_ids'] = None  
    elif dataset_choice == 'dfire':
        config['dataset_choice'] = 'dfire'
        config['dfire_root'] = os.path.join('..', 'data_subsets', 'D-Fire')  
        config['split_name'] = "train"  
        config['data_root'] = os.path.join(config['dfire_root'], config['split_name'])
        config['target_img_size'] = (128, 128)  
        config['color_spaces_to_load'] = ['bgr', 'hsv', 'ycbcr']  
        config['normalize_pixels'] = 1  
        config['fire_class_ids'] = [0, 1]  
    else:
        raise ValueError(f"Unknown dataset choice: {dataset_choice}. Choose 'kaggle' or 'dfire'.")

    print(f"Using dataset: {config['dataset_choice']}")
    print(f"Data root: {config.get('data_root')}")
    print(f"Target image size: {config['target_img_size']}")
    print(f"Color spaces loaded: {config['color_spaces_to_load']}")
    print(f"Normalize pixels: {bool(config['normalize_pixels'])}")
    if dataset_choice == 'dfire':
         print(f"D-Fire Split: {config['split_name']}")
         print(f"D-Fire Fire Class IDs: {config['fire_class_ids']}")
    return config

def get_feature_params():
    feature_params = {
        'hist_bins': 100,  
        'lbp_radius': 3,  
        'lbp_n_points': None,  
        'lbp_method': 'uniform',  
        'hog_orientations': 9,  
        'hog_pixels_per_cell': (8, 8),  
        'hog_cells_per_block': (2, 2),  
        'hog_block_norm': 'L2-Hys'  
    }
    print("\nFeature extraction parameters:", feature_params)
    return feature_params

def split_data(features_array, labels_array, test_size=0.2, random_state=42):
    if features_array.shape[0] == 0:
        print("Feature array is empty, cannot split.")
        return None, None, None, None

    print(f"\nSplitting data: training ({1-test_size:.0%}) testing ({test_size:.0%})")
     
    X_train, X_test, y_train, y_test = train_test_split(
        features_array,
        labels_array,
        test_size=test_size,
        random_state=random_state,
        stratify=labels_array
    )

    print(f"Training features shape: {X_train.shape}")
    print(f"Testing features shape: {X_test.shape}")
    print(f"Training labels shape: {y_train.shape}")
    print(f"Testing labels shape: {y_test.shape}")
    
    train_labels, train_counts = np.unique(y_train, return_counts=True)
    test_labels, test_counts = np.unique(y_test, return_counts=True)
    print(f"Train label distribution: {dict(zip(train_labels, train_counts))}")
    print(f"Test label distribution: {dict(zip(test_labels, test_counts))}")

    return X_train, X_test, y_train, y_test

def scale_features(X_train, X_test):
    if X_train is None or X_test is None or X_train.shape[0] == 0:
         print("Scaling skipped: train or test data is empty.")
         return None, None, None
    print("\nScaling features...")
    scaler = StandardScaler()
    
    X_train_scaled = scaler.fit_transform(X_train)
    X_test_scaled = scaler.transform(X_test)
    print("Scaling complete.")
    return X_train_scaled, X_test_scaled, scaler

def perform_correlation_selection(X_train, y_train, X_test, k_features):
    if X_train is None or X_test is None or X_train.shape[0] == 0:
         print("Correlation Selection skipped: train or test data is empty.")
         return None, None, None

    n_total_features = X_train.shape[1]
    k_features_int = k_features

    if isinstance(k_features, str) and k_features.endswith('%'):
        try:
            percentage = float(k_features[:-1]) / 100.0
            k_features_int = max(1, int(n_total_features * percentage))  
            print(f"Selecting top {k_features_int} features based on {percentage_str} percentage using Correlation...")
        except ValueError:
            print(f"Invalid percentage string for k_features: {k_features}. Skipping selection.")
            return X_train, X_test, None
    elif k_features == 'all':
         print("Selecting all features (no correlation selection)...")
         return X_train, X_test, None  
    elif isinstance(k_features, int) and k_features > 0:
        k_features_int = min(k_features, n_total_features)  
        print(f"Selecting top {k_features_int} features by correlation...")
    else:
        print(f"Invalid k_features value: {k_features}. Must be int > 0, 'all', or percentage string (e.g., '75%'). Skipping selection.")
        return X_train, X_test, None

     
    if k_features_int <= 0 or k_features_int > n_total_features:
         print(f"Calculated number of features to select ({k_features_int}) is invalid. Skipping selection.")
         return X_train, X_test, None
    if k_features_int == n_total_features:
         print("Number of features to select is equal to total features. Skipping selection.")
         return X_train, X_test, None

    selector = SelectKBest(score_func=f_classif, k=k_features_int)
    selector.fit(X_train, y_train)  

    X_train_selected = selector.transform(X_train)
    X_test_selected = selector.transform(X_test)

    print(f"Original feature shape: {X_train.shape}")
    print(f"Selected feature shape: {X_train_selected.shape}")

    return X_train_selected, X_test_selected, selector

def perform_rfe_selection(X_train, y_train, X_test, n_features_to_select, step=0.1, estimator=None):
    if X_train is None or X_test is None or X_train.shape[0] == 0:
         print("RFE Selection skipped: train or test data is empty.")
         return None, None, None

    n_total_features = X_train.shape[1]
    n_features_int = n_features_to_select

    if estimator is None:
        estimator = LogisticRegression(solver='liblinear', random_state=42, max_iter=2000)
         
    if isinstance(n_features_to_select, str) and n_features_to_select.endswith('%'):
        try:
            percentage = float(n_features_to_select[:-1]) / 100.0
            n_features_int = max(1, int(n_total_features * percentage))  
            print(f"Selecting top {n_features_int} features based on {percentage_str} percentage using RFE...")
        except ValueError:
            print(f"Invalid percentage string for n_features_to_select: {n_features_to_select}. Skipping RFE.")
            return X_train, X_test, None
    elif isinstance(n_features_to_select, int) and n_features_to_select > 0:
        n_features_int = min(n_features_to_select, n_total_features)  
        print(f"Selecting {n_features_int} features using RFE...")
    elif n_features_to_select == 'auto':
        print("RFE with 'auto' feature selection requires RFECV, which is not implemented in this helper. Skipping selection.")
        return X_train, X_test, None  
    else:
        print(f"Invalid n_features_to_select value: {n_features_to_select}. Skipping RFE.")
        return X_train, X_test, None

    if n_features_int <= 0 or n_features_int > n_total_features:
        print(f"Calculated number of features for RFE ({n_features_int}) is invalid. Skipping selection.")
        return X_train, X_test, None
    if n_features_int == n_total_features:
        print("Number of features to select is equal to total features. Skipping selection.")
        return X_train, X_test, None

    try:         
        if n_features_int >= n_total_features:
            print("Number of features to select is >= total features. Skipping RFE selection.")
            return X_train, X_test, None  

        rfe = RFE(estimator=estimator, n_features_to_select=n_features_int, step=step)
        rfe.fit(X_train, y_train)  

        X_train_selected = rfe.transform(X_train)
        X_test_selected = rfe.transform(X_test)

        print(f"Original feature shape: {X_train.shape}")
        print(f"Selected feature shape: {X_train_selected.shape}")

        return X_train_selected, X_test_selected, rfe
    except Exception as e:
        print(f"Error during RFE fit/transform: {e}")
        return X_train, X_test, None  

def tune_model_hyperparameters(model_estimator, X_train, y_train, param_grid, cv_strategy, scoring='f1', search_method='GridSearch'):
    if X_train is None or y_train is None or X_train.shape[0] == 0:
        print("Hyperparameter tuning skipped: training data is empty.")
        return None

    print(f"\nPerforming {search_method} tuning (scoring='{scoring}')...")
    start_time = time.time()

    if search_method == 'GridSearch':
        search_cv = GridSearchCV(
            estimator=model_estimator,
            param_grid=param_grid,
            cv=cv_strategy,
            scoring=scoring,
            n_jobs=4,
            verbose=1
        )
    elif search_method == 'RandomSearch':
          
         n_iter_search = 20  
         search_cv = RandomizedSearchCV(
            estimator=model_estimator,
            param_distributions=param_grid,  
            n_iter=n_iter_search,
            cv=cv_strategy,
            scoring=scoring,
            n_jobs=4,
            verbose=1,
            random_state=42
         )
    else:
        print(f"Unknown search_method: {search_method}. Use 'GridSearch' or 'RandomSearch'.")
        return None

    search_cv.fit(X_train, y_train)

    end_time = time.time()
    print(f"{search_method} duration: {end_time - start_time:.2f} seconds")
    print("\nBest parameters found:")
    print(search_cv.best_params_)
    print("\nBest CV score:")
    print(search_cv.best_score_)

    return search_cv

def evaluate_model(model, X_test, y_test, model_name="Model", feature_set_name="Unknown Feature Set"):
    if model is None or X_test is None or y_test is None or X_test.shape[0] == 0:
        print(f"{model_name} evaluation skipped on {feature_set_name}: model not trained or test data is empty.")
        return {}

    print(f"\nEvaluating {model_name} on the test set using {feature_set_name}...")
    start_time = time.time()
    y_pred = model.predict(X_test)
    end_time = time.time()
    print(f"Prediction duration: {end_time - start_time:.4f} seconds")

    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)
    conf_matrix = confusion_matrix(y_test, y_pred)
    
    print(f"Accuracy: {accuracy:.4f}")
    print(f"Precision: {precision:.4f}")
    print(f"Recall (Sensitivity): {recall:.4f}")
    print(f"F1 Score: {f1:.4f}")

    print(f"\nConfusion Matrix ({model_name} on {feature_set_name}):")
    print(conf_matrix)

    return {
        'accuracy': accuracy,
        'precision': precision,
        'recall': recall,
        'f1_score': f1,
        'confusion_matrix': conf_matrix.tolist()  
    }

def perform_pca_dimension_reduction(X_train, X_test, n_components):
    if X_train is None or X_test is None or X_train.shape[0] == 0:
        print("PCA skipped bc the data is empty..")
        return None, None, None

    try:
        n_total_features = X_train.shape[1]
        if isinstance(n_components, float) and 0 < n_components < 1:
            print(f"Applying PCA to retain {n_components:.0%} of variance...")
        elif isinstance(n_components, int) and 0 < n_components < n_total_features:
            print(f"Applying PCA to reduce to {n_components} components...")
        else: return X_train, X_test, None
        pca = PCA(n_components=n_components, random_state=42) # didn't wanna ruin a convention that came from a pop cultural joke
        X_train_pca = pca.fit_transform(X_train)
        X_test_pca = pca.transform(X_test)

        print(f"Original feature shape: {X_train.shape}")
        print(f"PCA transformed feature shape: {X_train_pca.shape}")
        print(f"Explained variance ratio with {pca.n_components_} components: {np.sum(pca.explained_variance_ratio_):.4f}")

        return X_train_pca, X_test_pca, pca
    except Exception as e:
        print(f"Error during PCA: {e}")
        return X_train, X_test, None
 
print("Imports and helper functions loaded.")
# Out:
# Imports and helper functions loaded.

# %%
dataset_choice = 'dfire'  

try:
    config = get_config(dataset_choice)
    feature_params = get_feature_params()
    features_array_orig, labels_array = load_and_extract_features_memory_safe(config, feature_params)

except ValueError as e:
    print(f"Configuration Error: {e}")
    features_array_orig = np.array([])
    labels_array = np.array([])
except FileNotFoundError as e:
    print(f"File Not Found Error: {e}. Please check data paths in get_config.")
    features_array_orig = np.array([])
    labels_array = np.array([])
except Exception as e:
    print(f"An unexpected error occurred during data loading and feature extraction: {e}")
    features_array_orig = np.array([])
    labels_array = np.array([])

if features_array_orig.shape[0] == 0:
    print("No features loaded. Cannot proceed with splitting or modeling.")
    X_train_orig, X_test_orig, y_train, y_test = None, None, None, None
    X_train_scaled, X_test_scaled, scaler = None, None, None
    feature_sets = {}
    feature_transformers = {}
else:
    print("\n--- Splitting Data ---")
    X_train_orig, X_test_orig, y_train, y_test = split_data(features_array_orig, labels_array, test_size=0.2, random_state=42)
    print("\n--- Scaling Features (Initial) ---")
    X_train_scaled, X_test_scaled, scaler = scale_features(X_train_orig, X_test_orig)
    feature_sets = {'Scaled_All': (X_train_scaled, X_test_scaled)}
    feature_transformers = {'Scaled_All': scaler}
# Out:
# Using dataset: dfire
# Data root: ..\data_subsets\D-Fire\train
# Target image size: (128, 128)
# Color spaces loaded: ['bgr', 'hsv', 'ycbcr']
# Normalize pixels: True
# D-Fire Split: train
# D-Fire Fire Class IDs: [0, 1]
#
# Feature extraction parameters: {'hist_bins': 100, 'lbp_radius': 3, 'lbp_n_points': None, 'lbp_method': 'uniform', 'hog_orientations': 9, 'hog_pixels_per_cell': (8, 8), 'hog_cells_per_block': (2, 2), 'hog_block_norm': 'L2-Hys'}
# Determining Labels...
# Label determination complete.
# Loading images and extracting features...
# Feature extraction complete.
# Total images initially found: 1629
# Images skipped (read error): 0
# Images skipped (feature error): 0
# Images successfully processed: 1629
# Final features array shape: (1629, 8526)
# Final labels array shape: (1629,)
#
# --- Splitting Data ---
#
# Splitting data: training (80%) testing (20%)
# Training features shape: (1303, 8526)
# Testing features shape: (326, 8526)
# Training labels shape: (1303,)
# Testing labels shape: (326,)
# Train label distribution: {0: 663, 1: 640}
# Test label distribution: {0: 166, 1: 160}
#
# --- Scaling Features (Initial) ---
#
# Scaling features...
# Scaling complete.

# %%
if X_train_scaled is not None and y_train is not None:
    print("\n--- Performing Feature Engineering (Selection) ---")
    original_feature_count = X_train_scaled.shape[1]
    print(f"Starting with {original_feature_count} features after scaling.") 
    corr_feature_percentages = ['75%', '50%']

    for percentage_str in corr_feature_percentages:
        print(f"\nAttempting Correlation Selection with {percentage_str}...")
        try:
            X_train_corr, X_test_corr, corr_selector = perform_correlation_selection(
                X_train_scaled, y_train, X_test_scaled, k_features=percentage_str
            )
            if X_train_corr is not None and X_train_corr.shape[1] < original_feature_count:
                feature_sets[f'Scaled_Corr{percentage_str}'] = (X_train_corr, X_test_corr)
                feature_transformers[f'Scaled_Corr{percentage_str}'] = corr_selector
            else:
                 print(f"Correlation Selection with {percentage_str} did not reduce features or failed.")
        except Exception as e:
            print(f"Error during Correlation Selection ({percentage_str}): {e}")

    rfe_feature_percentages = ['75%', '50%']     
    rfe_step_val = 0.1  
    rfe_estimator = LogisticRegression(solver='liblinear', random_state=42, max_iter=2000)
    for percentage_str in rfe_feature_percentages:
         print(f"\nAttempting RFE Selection with {percentage_str} (step={rfe_step_val})...")
         try:
            X_train_rfe, X_test_rfe, rfe_selector = perform_rfe_selection(
                X_train_scaled, y_train, X_test_scaled, n_features_to_select=percentage_str, step=rfe_step_val, estimator=rfe_estimator
            )
            if X_train_rfe is not None and X_train_rfe.shape[1] < original_feature_count:
                feature_sets[f'Scaled_RFE{percentage_str}'] = (X_train_rfe, X_test_rfe)
                feature_transformers[f'Scaled_RFE{percentage_str}'] = rfe_selector
            else:
                 print(f"RFE Selection with {percentage_str} did not reduce features or failed.")
         except Exception as e:
            print(f"Error during RFE Selection ({percentage_str}): {e}")

    print("\n--- Available Feature Sets for Tuning ---")
    for name, (X_train_fs, _) in feature_sets.items():
        print(f"- {name}: {X_train_fs.shape[1]} features, before PCA..")
    
    pca_components= [0.95, 1000] # aiming for .95 variance retention & 1000 feature for first trial
    for n_comp in pca_components:
        print(f"\nPCA with n_components={n_comp}...")
        try:
            X_train_pca, X_test_pca, pca_transformer = perform_pca_dimension_reduction(X_train_scaled, X_test_scaled, n_components=n_comp)
            if X_train_pca is not None and X_train_pca.shape[1] < original_feature_count:
                fs_name_suffix = f"{int(n_comp*100)}%" if isinstance(n_comp, float) else str(n_comp)
                fs_name = f'Scaled_PCA_{fs_name_suffix}'
                feature_sets[fs_name] = (X_train_pca, X_test_pca)
                feature_transformers[fs_name] = pca_transformer
            else:
                print(f"n_components={n_comp} failed..")
        except Exception as e:
            print(f"error during n_components={n_comp}: {e}")

    print("\n--- AFTER PCA: ---")
    for name, (X_train_fs, _) in feature_sets.items():
        print(f"- {name}: {X_train_fs.shape[1]} features")

else:
    print("Skipping feature engineering as scaled data is not available.")
# Out:
# --- Performing Feature Engineering (Selection) ---
# Starting with 8526 features after scaling.
#
# Attempting Correlation Selection with 75%...
# Selecting top 6394 features based on 75% percentage using Correlation...
# Original feature shape: (1303, 8526)
# Selected feature shape: (1303, 6394)
#
# Attempting Correlation Selection with 50%...
# Selecting top 4263 features based on 50% percentage using Correlation...
# Original feature shape: (1303, 8526)
# Selected feature shape: (1303, 4263)
#
# Attempting RFE Selection with 75% (step=0.1)...
# Selecting top 6394 features based on 75% percentage using RFE...
# Original feature shape: (1303, 8526)
# Selected feature shape: (1303, 6394)
#
# Attempting RFE Selection with 50% (step=0.1)...
# Selecting top 4263 features based on 50% percentage using RFE...
# Original feature shape: (1303, 8526)
# Selected feature shape: (1303, 4263)
#
# --- Available Feature Sets for Tuning ---
# - Scaled_All: 8526 features, before PCA..
# - Scaled_Corr75%: 6394 features, before PCA..
# - Scaled_Corr50%: 4263 features, before PCA..
# - Scaled_RFE75%: 6394 features, before PCA..
# - Scaled_RFE50%: 4263 features, before PCA..
#
# PCA with n_components=0.95...
# Applying PCA to retain 95% of variance...
# Original feature shape: (1303, 8526)
# PCA transformed feature shape: (1303, 814)
# Explained variance ratio with 814 components: 0.9501
#
# PCA with n_components=1000...
# Applying PCA to reduce to 1000 components...
# Original feature shape: (1303, 8526)
# PCA transformed feature shape: (1303, 1000)
# Explained variance ratio with 1000 components: 0.9791
#
# --- AFTER PCA: ---
# - Scaled_All: 8526 features
# - Scaled_Corr75%: 6394 features
# - Scaled_Corr50%: 4263 features
# - Scaled_RFE75%: 6394 features
# - Scaled_RFE50%: 4263 features
# - Scaled_PCA_95%: 814 features
# - Scaled_PCA_1000: 1000 features

# %%
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, BatchNormalization, Dropout, LeakyReLU, Input
from scikeras.wrappers import KerasClassifier
def create_custom_mlp(hidden_layer_1_neurons=128, hidden_layer_2_neurons=64,
                        dropout_rate=0.3, activation='leaky_relu', learning_rate=0.001,
                        meta=None):
    n_features_in = meta["n_features_in_"]
    
    model = Sequential()
    model.add(Input(shape=(n_features_in,)))
    model.add(Dense(hidden_layer_1_neurons))
    model.add(BatchNormalization())
    if activation == 'leaky_relu': model.add(LeakyReLU(alpha=0.1))
    else: model.add(tf.keras.layers.ReLU())
    model.add(Dropout(dropout_rate))
    if hidden_layer_2_neurons is not None and hidden_layer_2_neurons > 0:
        model.add(Dense(hidden_layer_2_neurons))
        model.add(BatchNormalization())
        if activation == 'leaky_relu': model.add(LeakyReLU(alpha=0.1))
        else: model.add(tf.keras.layers.ReLU())
        model.add(Dropout(dropout_rate))
    
    model.add(Dense(1, activation='sigmoid'))
    optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)
    model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])
    return model

# %%
if not feature_sets or y_train is None:
    print("Skipping model training and tuning: No feature sets available or labels are missing.")
else:
    print("\n--- Starting Model Training and Hyperparameter Tuning ---")
    models_to_tune = {
        'SVM': {
            'estimator': SVC(random_state=42),
            'param_grid': {
                'C': [0.1, 1, 10, 50], # 50, 100
                'gamma': ['scale', 'auto', 0.001, 0.01, 0.1, 1], # 0.001
                'kernel': ['rbf', 'linear']
            }
        },
        'LightGBM': {
            'estimator': lgb.LGBMClassifier(random_state=42, objective='binary', metric='binary_logloss', verbosity=-1),  
            'param_grid': {
                'n_estimators': [50, 100, 150],      
                'learning_rate': [0.01, 0.05, 0.1],   
                'max_depth': [-1, 10, 20],           
                'num_leaves': [31, 50, 70],          
                'subsample': [0.8, 0.9],              
                'colsample_bytree': [0.8, 0.9, 1.0],
                'min_split_gain': [0.1],    
                'min_child_samples': [5]   
            }
        },
        'Custom_MLP': {
            'estimator': KerasClassifier(
                model=create_custom_mlp,
                loss=tf.keras.losses.BinaryCrossentropy,
                epochs=100,
                batch_size=32,
                verbose=1, # çıktı ayarı
                validation_split=0.2, # early stopping
                callbacks=[tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=15, verbose=0, restore_best_weights=True)]
            ),
            'param_grid': {
                'model__hidden_layer_1_neurons': [64, 128, 256],
                'model__hidden_layer_2_neurons': [0, 64, 128],
                'model__dropout_rate': [0.2, 0.4, 0.6],
                'model__activation': ['relu', 'leaky_relu'],
                'optimizer__learning_rate': [0.001, 0.005, 0.01]
            }
        }
    }
    cv_strategy = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
    scoring_metric = 'f1'   
    all_results = {}
    best_overall_test_score = -np.inf  
    best_overall_combination = None
    best_overall_trained_model = None
    best_overall_X_test = None  
    best_overall_transformer = None  
 
    for model_name, model_config in models_to_tune.items():
        all_results[model_name] = {}
        estimator = model_config['estimator']
        param_grid = model_config['param_grid']

        print(f"\n\n=== Training and Tuning {model_name} ===")
        for fs_name, (X_train_fs, X_test_fs) in feature_sets.items():
            print(f"\n--- Tuning {model_name} on Feature Set: {fs_name} ({X_train_fs.shape[1]} features) ---")
            if X_train_fs is None or X_train_fs.shape[0] == 0:
                print(f"Skipping tuning for {model_name} on {fs_name}: Training data is empty.")
                continue
            tuned_search = tune_model_hyperparameters(
                estimator,
                X_train_fs,
                y_train,
                param_grid=param_grid,
                cv_strategy=cv_strategy,
                scoring=scoring_metric,
                search_method='RandomSearch'  
            )

            if tuned_search:
                best_model_for_combination = tuned_search.best_estimator_
                best_cv_score = tuned_search.best_score_
                best_params = tuned_search.best_params_
                print(f"Best CV {scoring_metric} for {model_name} on {fs_name}: {best_cv_score:.4f}")
                test_metrics = evaluate_model(best_model_for_combination, X_test_fs, y_test, model_name, fs_name)
                all_results[model_name][fs_name] = {
                    'best_cv_score': best_cv_score,
                    'best_params': best_params,
                    'test_metrics': test_metrics,
                    'trained_model': best_model_for_combination,
                    'transformer': feature_transformers.get(fs_name)  
                }

                if test_metrics and test_metrics.get('f1_score', -np.inf) > best_overall_test_score:
                    best_overall_test_score = test_metrics['f1_score']
                    best_overall_combination = (model_name, fs_name)
                    best_overall_trained_model = best_model_for_combination
                    best_overall_X_test = X_test_fs  
                    best_overall_transformer = feature_transformers.get(fs_name)  
    print("\n--- Model Training and Hyperparameter Tuning Complete ---")
# Out:
# --- Starting Model Training and Hyperparameter Tuning ---
#
#
# === Training and Tuning SVM ===
#
# --- Tuning SVM on Feature Set: Scaled_All (8526 features) ---
#
# Performing RandomSearch tuning (scoring='f1')...
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# RandomSearch duration: 339.44 seconds
#
# Best parameters found:
# {'kernel': 'rbf', 'gamma': 'auto', 'C': 10}
#
# Best CV score:
# 0.7852542037010484
# Best CV f1 for SVM on Scaled_All: 0.7853
#
# Evaluating SVM on the test set using Scaled_All...
# Prediction duration: 2.3331 seconds
# Accuracy: 0.8313
# Precision: 0.7933
# Recall (Sensitivity): 0.8875
# F1 Score: 0.8378
#
# Confusion Matrix (SVM on Scaled_All):
# [[129  37]
#  [ 18 142]]
#
# --- Tuning SVM on Feature Set: Scaled_Corr75% (6394 features) ---
#
# Performing RandomSearch tuning (scoring='f1')...
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# RandomSearch duration: 213.87 seconds
#
# Best parameters found:
# {'kernel': 'rbf', 'gamma': 'auto', 'C': 10}
#
# Best CV score:
# 0.7823153151349909
# Best CV f1 for SVM on Scaled_Corr75%: 0.7823
#
# Evaluating SVM on the test set using Scaled_Corr75%...
# Prediction duration: 1.9614 seconds
# Accuracy: 0.8282
# Precision: 0.7989
# Recall (Sensitivity): 0.8688
# F1 Score: 0.8323
#
# Confusion Matrix (SVM on Scaled_Corr75%):
# [[131  35]
#  [ 21 139]]
#
# --- Tuning SVM on Feature Set: Scaled_Corr50% (4263 features) ---
#
# Performing RandomSearch tuning (scoring='f1')...
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# RandomSearch duration: 140.70 seconds
#
# Best parameters found:
# {'kernel': 'rbf', 'gamma': 'auto', 'C': 10}
#
# Best CV score:
# 0.786027957575913
# Best CV f1 for SVM on Scaled_Corr50%: 0.7860
#
# Evaluating SVM on the test set using Scaled_Corr50%...
# Prediction duration: 1.1813 seconds
# Accuracy: 0.8252
# Precision: 0.8012
# Recall (Sensitivity): 0.8562
# F1 Score: 0.8278
#
# Confusion Matrix (SVM on Scaled_Corr50%):
# [[132  34]
#  [ 23 137]]
#
# --- Tuning SVM on Feature Set: Scaled_RFE75% (6394 features) ---
#
# Performing RandomSearch tuning (scoring='f1')...
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# RandomSearch duration: 269.30 seconds
#
# Best parameters found:
# {'kernel': 'rbf', 'gamma': 'auto', 'C': 10}
#
# Best CV score:
# 0.8100075258010172
# Best CV f1 for SVM on Scaled_RFE75%: 0.8100
#
# Evaluating SVM on the test set using Scaled_RFE75%...
# Prediction duration: 1.6421 seconds
# Accuracy: 0.8344
# Precision: 0.8011
# Recall (Sensitivity): 0.8812
# F1 Score: 0.8393
#
# Confusion Matrix (SVM on Scaled_RFE75%):
# [[131  35]
#  [ 19 141]]
#
# --- Tuning SVM on Feature Set: Scaled_RFE50% (4263 features) ---
#
# Performing RandomSearch tuning (scoring='f1')...
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# RandomSearch duration: 151.82 seconds
#
# Best parameters found:
# {'kernel': 'linear', 'gamma': 'auto', 'C': 10}
#
# Best CV score:
# 0.8994826819230688
# Best CV f1 for SVM on Scaled_RFE50%: 0.8995
#
# Evaluating SVM on the test set using Scaled_RFE50%...
# Prediction duration: 0.5988 seconds
# Accuracy: 0.7270
# Precision: 0.6940
# Recall (Sensitivity): 0.7937
# F1 Score: 0.7405
#
# Confusion Matrix (SVM on Scaled_RFE50%):
# [[110  56]
#  [ 33 127]]
#
# --- Tuning SVM on Feature Set: Scaled_PCA_95% (814 features) ---
#
# Performing RandomSearch tuning (scoring='f1')...
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# RandomSearch duration: 17.81 seconds
#
# Best parameters found:
# {'kernel': 'rbf', 'gamma': 'scale', 'C': 10}
#
# Best CV score:
# 0.7872968518383732
# Best CV f1 for SVM on Scaled_PCA_95%: 0.7873
#
# Evaluating SVM on the test set using Scaled_PCA_95%...
# Prediction duration: 0.1597 seconds
# Accuracy: 0.8252
# Precision: 0.7910
# Recall (Sensitivity): 0.8750
# F1 Score: 0.8309
#
# Confusion Matrix (SVM on Scaled_PCA_95%):
# [[129  37]
#  [ 20 140]]
#
# --- Tuning SVM on Feature Set: Scaled_PCA_1000 (1000 features) ---
#
# Performing RandomSearch tuning (scoring='f1')...
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# RandomSearch duration: 20.74 seconds
#
# Best parameters found:
# {'kernel': 'rbf', 'gamma': 'scale', 'C': 10}
#
# Best CV score:
# 0.7883172544849878
# Best CV f1 for SVM on Scaled_PCA_1000: 0.7883
#
# Evaluating SVM on the test set using Scaled_PCA_1000...
# Prediction duration: 0.2051 seconds
# Accuracy: 0.8344
# Precision: 0.7978
# Recall (Sensitivity): 0.8875
# F1 Score: 0.8402
#
# Confusion Matrix (SVM on Scaled_PCA_1000):
# [[130  36]
#  [ 18 142]]
#
#
# === Training and Tuning LightGBM ===
#
# --- Tuning LightGBM on Feature Set: Scaled_All (8526 features) ---
#
# Performing RandomSearch tuning (scoring='f1')...
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# RandomSearch duration: 3267.93 seconds
#
# Best parameters found:
# {'subsample': 0.9, 'num_leaves': 31, 'n_estimators': 150, 'min_split_gain': 0.1, 'min_child_samples': 5, 'max_depth': -1, 'learning_rate': 0.05, 'colsample_bytree': 1.0}
#
# Best CV score:
# 0.7571917094466565
# Best CV f1 for LightGBM on Scaled_All: 0.7572
#
# Evaluating LightGBM on the test set using Scaled_All...
# Prediction duration: 0.7403 seconds
# Accuracy: 0.7822
# Precision: 0.7486
# Recall (Sensitivity): 0.8375
# F1 Score: 0.7906
#
# Confusion Matrix (LightGBM on Scaled_All):
# [[121  45]
#  [ 26 134]]
#
# --- Tuning LightGBM on Feature Set: Scaled_Corr75% (6394 features) ---
#
# Performing RandomSearch tuning (scoring='f1')...
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# RandomSearch duration: 2621.81 seconds
#
# Best parameters found:
# {'subsample': 0.8, 'num_leaves': 31, 'n_estimators': 150, 'min_split_gain': 0.1, 'min_child_samples': 5, 'max_depth': 10, 'learning_rate': 0.05, 'colsample_bytree': 0.8}
#
# Best CV score:
# 0.7549470356832797
# Best CV f1 for LightGBM on Scaled_Corr75%: 0.7549
#
# Evaluating LightGBM on the test set using Scaled_Corr75%...
# Prediction duration: 0.1664 seconds
# Accuracy: 0.8006
# Precision: 0.7950
# Recall (Sensitivity): 0.8000
# F1 Score: 0.7975
#
# Confusion Matrix (LightGBM on Scaled_Corr75%):
# [[133  33]
#  [ 32 128]]
#
# --- Tuning LightGBM on Feature Set: Scaled_Corr50% (4263 features) ---
#
# Performing RandomSearch tuning (scoring='f1')...
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# RandomSearch duration: 1526.62 seconds
#
# Best parameters found:
# {'subsample': 0.8, 'num_leaves': 31, 'n_estimators': 150, 'min_split_gain': 0.1, 'min_child_samples': 5, 'max_depth': 10, 'learning_rate': 0.05, 'colsample_bytree': 0.8}
#
# Best CV score:
# 0.7734268510731441
# Best CV f1 for LightGBM on Scaled_Corr50%: 0.7734
#
# Evaluating LightGBM on the test set using Scaled_Corr50%...
# Prediction duration: 0.0189 seconds
# Accuracy: 0.8129
# Precision: 0.7829
# Recall (Sensitivity): 0.8562
# F1 Score: 0.8179
#
# Confusion Matrix (LightGBM on Scaled_Corr50%):
# [[128  38]
#  [ 23 137]]
#
# --- Tuning LightGBM on Feature Set: Scaled_RFE75% (6394 features) ---
#
# Performing RandomSearch tuning (scoring='f1')...
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# RandomSearch duration: 2247.05 seconds
#
# Best parameters found:
# {'subsample': 0.9, 'num_leaves': 31, 'n_estimators': 150, 'min_split_gain': 0.1, 'min_child_samples': 5, 'max_depth': -1, 'learning_rate': 0.05, 'colsample_bytree': 1.0}
#
# Best CV score:
# 0.7610264374276555
# Best CV f1 for LightGBM on Scaled_RFE75%: 0.7610
#
# Evaluating LightGBM on the test set using Scaled_RFE75%...
# Prediction duration: 0.0140 seconds
# Accuracy: 0.7945
# Precision: 0.7598
# Recall (Sensitivity): 0.8500
# F1 Score: 0.8024
#
# Confusion Matrix (LightGBM on Scaled_RFE75%):
# [[123  43]
#  [ 24 136]]
#
# --- Tuning LightGBM on Feature Set: Scaled_RFE50% (4263 features) ---
#
# Performing RandomSearch tuning (scoring='f1')...
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# RandomSearch duration: 1758.87 seconds
#
# Best parameters found:
# {'subsample': 0.8, 'num_leaves': 31, 'n_estimators': 150, 'min_split_gain': 0.1, 'min_child_samples': 5, 'max_depth': 10, 'learning_rate': 0.05, 'colsample_bytree': 0.8}
#
# Best CV score:
# 0.7762311068148391
# Best CV f1 for LightGBM on Scaled_RFE50%: 0.7762
#
# Evaluating LightGBM on the test set using Scaled_RFE50%...
# Prediction duration: 0.0160 seconds
# Accuracy: 0.7945
# Precision: 0.7688
# Recall (Sensitivity): 0.8313
# F1 Score: 0.7988
#
# Confusion Matrix (LightGBM on Scaled_RFE50%):
# [[126  40]
#  [ 27 133]]
#
# --- Tuning LightGBM on Feature Set: Scaled_PCA_95% (814 features) ---
#
# Performing RandomSearch tuning (scoring='f1')...
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# RandomSearch duration: 361.81 seconds
#
# Best parameters found:
# {'subsample': 0.8, 'num_leaves': 31, 'n_estimators': 150, 'min_split_gain': 0.1, 'min_child_samples': 5, 'max_depth': 10, 'learning_rate': 0.05, 'colsample_bytree': 0.8}
#
# Best CV score:
# 0.7101857931418513
# Best CV f1 for LightGBM on Scaled_PCA_95%: 0.7102
#
# Evaluating LightGBM on the test set using Scaled_PCA_95%...
# Prediction duration: 0.0350 seconds
# Accuracy: 0.7914
# Precision: 0.8382
# Recall (Sensitivity): 0.7125
# F1 Score: 0.7703
#
# Confusion Matrix (LightGBM on Scaled_PCA_95%):
# [[144  22]
#  [ 46 114]]
#
# --- Tuning LightGBM on Feature Set: Scaled_PCA_1000 (1000 features) ---
#
# Performing RandomSearch tuning (scoring='f1')...
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# RandomSearch duration: 441.70 seconds
#
# Best parameters found:
# {'subsample': 0.9, 'num_leaves': 31, 'n_estimators': 150, 'min_split_gain': 0.1, 'min_child_samples': 5, 'max_depth': -1, 'learning_rate': 0.05, 'colsample_bytree': 0.9}
#
# Best CV score:
# 0.7250805441712023
# Best CV f1 for LightGBM on Scaled_PCA_1000: 0.7251
#
# Evaluating LightGBM on the test set using Scaled_PCA_1000...
# Prediction duration: 0.0452 seconds
# Accuracy: 0.7515
# Precision: 0.7970
# Recall (Sensitivity): 0.6625
# F1 Score: 0.7235
#
# Confusion Matrix (LightGBM on Scaled_PCA_1000):
# [[139  27]
#  [ 54 106]]
#
#
# === Training and Tuning Custom_MLP ===
#
# --- Tuning Custom_MLP on Feature Set: Scaled_All (8526 features) ---
#
# Performing RandomSearch tuning (scoring='f1')...
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Epoch 1/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.5634 - loss: 0.7638 - val_accuracy: 0.7011 - val_loss: 0.7145
# Epoch 2/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8204 - loss: 0.3963 - val_accuracy: 0.7433 - val_loss: 0.5859
# Epoch 3/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9111 - loss: 0.2777 - val_accuracy: 0.7433 - val_loss: 0.5437
# Epoch 4/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9528 - loss: 0.2041 - val_accuracy: 0.7433 - val_loss: 0.5794
# Epoch 5/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9779 - loss: 0.1286 - val_accuracy: 0.7356 - val_loss: 0.6020
# Epoch 6/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9776 - loss: 0.0977 - val_accuracy: 0.7203 - val_loss: 0.6306
# Epoch 7/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9930 - loss: 0.0718 - val_accuracy: 0.7280 - val_loss: 0.6346
# Epoch 8/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9925 - loss: 0.0639 - val_accuracy: 0.7241 - val_loss: 0.6516
# Epoch 9/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9989 - loss: 0.0445 - val_accuracy: 0.7395 - val_loss: 0.6763
# Epoch 10/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9972 - loss: 0.0381 - val_accuracy: 0.7471 - val_loss: 0.6835
# Epoch 11/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9945 - loss: 0.0337 - val_accuracy: 0.7318 - val_loss: 0.7302
# Epoch 12/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9988 - loss: 0.0276 - val_accuracy: 0.7165 - val_loss: 0.7689
# Epoch 13/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9970 - loss: 0.0246 - val_accuracy: 0.7395 - val_loss: 0.7884
# Epoch 14/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9986 - loss: 0.0211 - val_accuracy: 0.7203 - val_loss: 0.7792
# Epoch 15/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9992 - loss: 0.0171 - val_accuracy: 0.7395 - val_loss: 0.8099
# Epoch 16/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9991 - loss: 0.0268 - val_accuracy: 0.7356 - val_loss: 0.8159
# Epoch 17/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0189 - val_accuracy: 0.7356 - val_loss: 0.8390
# Epoch 18/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0122 - val_accuracy: 0.7165 - val_loss: 0.8631
# RandomSearch duration: 629.74 seconds
#
# Best parameters found:
# {'optimizer__learning_rate': 0.01, 'model__hidden_layer_2_neurons': 0, 'model__hidden_layer_1_neurons': 64, 'model__dropout_rate': 0.4, 'model__activation': 'relu'}
#
# Best CV score:
# 0.758729868392644
# Best CV f1 for Custom_MLP on Scaled_All: 0.7587
#
# Evaluating Custom_MLP on the test set using Scaled_All...
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Prediction duration: 0.1416 seconds
# Accuracy: 0.7515
# Precision: 0.7232
# Recall (Sensitivity): 0.8000
# F1 Score: 0.7596
#
# Confusion Matrix (Custom_MLP on Scaled_All):
# [[117  49]
#  [ 32 128]]
#
# --- Tuning Custom_MLP on Feature Set: Scaled_Corr75% (6394 features) ---
#
# Performing RandomSearch tuning (scoring='f1')...
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Epoch 1/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.6369 - loss: 0.6862 - val_accuracy: 0.7088 - val_loss: 0.7787
# Epoch 2/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8558 - loss: 0.3882 - val_accuracy: 0.7356 - val_loss: 0.6229
# Epoch 3/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9332 - loss: 0.2054 - val_accuracy: 0.7165 - val_loss: 0.6502
# Epoch 4/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9718 - loss: 0.1266 - val_accuracy: 0.7586 - val_loss: 0.6940
# Epoch 5/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9804 - loss: 0.0841 - val_accuracy: 0.7356 - val_loss: 0.7151
# Epoch 6/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9935 - loss: 0.0523 - val_accuracy: 0.7548 - val_loss: 0.6863
# Epoch 7/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9937 - loss: 0.0470 - val_accuracy: 0.7625 - val_loss: 0.7000
# Epoch 8/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9984 - loss: 0.0256 - val_accuracy: 0.7701 - val_loss: 0.7257
# Epoch 9/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9953 - loss: 0.0271 - val_accuracy: 0.7548 - val_loss: 0.7804
# Epoch 10/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9947 - loss: 0.0306 - val_accuracy: 0.7663 - val_loss: 0.8294
# Epoch 11/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9931 - loss: 0.0336 - val_accuracy: 0.7625 - val_loss: 0.7220
# Epoch 12/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9993 - loss: 0.0166 - val_accuracy: 0.7739 - val_loss: 0.7921
# Epoch 13/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9983 - loss: 0.0156 - val_accuracy: 0.7586 - val_loss: 0.8461
# Epoch 14/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9995 - loss: 0.0126 - val_accuracy: 0.7625 - val_loss: 0.8496
# Epoch 15/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 1.0000 - loss: 0.0094 - val_accuracy: 0.7663 - val_loss: 0.8655
# Epoch 16/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9973 - loss: 0.0144 - val_accuracy: 0.7471 - val_loss: 0.9060
# Epoch 17/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9963 - loss: 0.0138 - val_accuracy: 0.7471 - val_loss: 0.9519
# RandomSearch duration: 481.31 seconds
#
# Best parameters found:
# {'optimizer__learning_rate': 0.01, 'model__hidden_layer_2_neurons': 64, 'model__hidden_layer_1_neurons': 256, 'model__dropout_rate': 0.2, 'model__activation': 'leaky_relu'}
#
# Best CV score:
# 0.7558070564193516
# Best CV f1 for Custom_MLP on Scaled_Corr75%: 0.7558
#
# Evaluating Custom_MLP on the test set using Scaled_Corr75%...
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Prediction duration: 0.2024 seconds
# Accuracy: 0.7730
# Precision: 0.7722
# Recall (Sensitivity): 0.7625
# F1 Score: 0.7673
#
# Confusion Matrix (Custom_MLP on Scaled_Corr75%):
# [[130  36]
#  [ 38 122]]
#
# --- Tuning Custom_MLP on Feature Set: Scaled_Corr50% (4263 features) ---
#
# Performing RandomSearch tuning (scoring='f1')...
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Epoch 1/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.6267 - loss: 0.7881 - val_accuracy: 0.6820 - val_loss: 0.8950
# Epoch 2/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9090 - loss: 0.2704 - val_accuracy: 0.7165 - val_loss: 0.6656
# Epoch 3/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9580 - loss: 0.1497 - val_accuracy: 0.7318 - val_loss: 0.6624
# Epoch 4/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9892 - loss: 0.0811 - val_accuracy: 0.7280 - val_loss: 0.6964
# Epoch 5/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9918 - loss: 0.0456 - val_accuracy: 0.7203 - val_loss: 0.7010
# Epoch 6/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9910 - loss: 0.0466 - val_accuracy: 0.7011 - val_loss: 0.7660
# Epoch 7/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9968 - loss: 0.0290 - val_accuracy: 0.7510 - val_loss: 0.7730
# Epoch 8/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9974 - loss: 0.0239 - val_accuracy: 0.7280 - val_loss: 0.7980
# Epoch 9/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9986 - loss: 0.0131 - val_accuracy: 0.7165 - val_loss: 0.8869
# Epoch 10/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9975 - loss: 0.0125 - val_accuracy: 0.7165 - val_loss: 0.8783
# Epoch 11/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9998 - loss: 0.0129 - val_accuracy: 0.7241 - val_loss: 0.8979
# Epoch 12/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9994 - loss: 0.0111 - val_accuracy: 0.7165 - val_loss: 0.9657
# Epoch 13/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9996 - loss: 0.0078 - val_accuracy: 0.7395 - val_loss: 0.9359
# Epoch 14/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9971 - loss: 0.0124 - val_accuracy: 0.7318 - val_loss: 1.0946
# Epoch 15/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9966 - loss: 0.0127 - val_accuracy: 0.7165 - val_loss: 1.0647
# Epoch 16/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9969 - loss: 0.0174 - val_accuracy: 0.7050 - val_loss: 1.1428
# Epoch 17/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9952 - loss: 0.0251 - val_accuracy: 0.7280 - val_loss: 1.0917
# Epoch 18/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9874 - loss: 0.0354 - val_accuracy: 0.7433 - val_loss: 1.0290
# RandomSearch duration: 341.71 seconds
#
# Best parameters found:
# {'optimizer__learning_rate': 0.01, 'model__hidden_layer_2_neurons': 0, 'model__hidden_layer_1_neurons': 256, 'model__dropout_rate': 0.2, 'model__activation': 'leaky_relu'}
#
# Best CV score:
# 0.7456900332353511
# Best CV f1 for Custom_MLP on Scaled_Corr50%: 0.7457
#
# Evaluating Custom_MLP on the test set using Scaled_Corr50%...
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Prediction duration: 0.1731 seconds
# Accuracy: 0.7515
# Precision: 0.7207
# Recall (Sensitivity): 0.8063
# F1 Score: 0.7611
#
# Confusion Matrix (Custom_MLP on Scaled_Corr50%):
# [[116  50]
#  [ 31 129]]
#
# --- Tuning Custom_MLP on Feature Set: Scaled_RFE75% (6394 features) ---
#
# Performing RandomSearch tuning (scoring='f1')...
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Epoch 1/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.6196 - loss: 0.8963 - val_accuracy: 0.7318 - val_loss: 0.8756
# Epoch 2/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.8880 - loss: 0.2709 - val_accuracy: 0.7701 - val_loss: 0.6018
# Epoch 3/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9704 - loss: 0.1354 - val_accuracy: 0.7893 - val_loss: 0.5786
# Epoch 4/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9897 - loss: 0.0693 - val_accuracy: 0.7893 - val_loss: 0.5427
# Epoch 5/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9899 - loss: 0.0584 - val_accuracy: 0.7931 - val_loss: 0.5129
# Epoch 6/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9952 - loss: 0.0324 - val_accuracy: 0.7778 - val_loss: 0.5380
# Epoch 7/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9989 - loss: 0.0163 - val_accuracy: 0.7778 - val_loss: 0.5569
# Epoch 8/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 1.0000 - loss: 0.0101 - val_accuracy: 0.7854 - val_loss: 0.5482
# Epoch 9/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 1.0000 - loss: 0.0089 - val_accuracy: 0.7931 - val_loss: 0.5599
# Epoch 10/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 1.0000 - loss: 0.0086 - val_accuracy: 0.7854 - val_loss: 0.5790
# Epoch 11/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 1.0000 - loss: 0.0067 - val_accuracy: 0.7854 - val_loss: 0.5859
# Epoch 12/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 1.0000 - loss: 0.0035 - val_accuracy: 0.7969 - val_loss: 0.5824
# Epoch 13/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 1.0000 - loss: 0.0066 - val_accuracy: 0.7931 - val_loss: 0.6248
# Epoch 14/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 1.0000 - loss: 0.0040 - val_accuracy: 0.7969 - val_loss: 0.6168
# Epoch 15/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 0.0042 - val_accuracy: 0.7854 - val_loss: 0.6230
# Epoch 16/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 1.0000 - loss: 0.0028 - val_accuracy: 0.7816 - val_loss: 0.6292
# Epoch 17/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9998 - loss: 0.0030 - val_accuracy: 0.7931 - val_loss: 0.6231
# Epoch 18/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9987 - loss: 0.0055 - val_accuracy: 0.7739 - val_loss: 0.6471
# Epoch 19/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 1.0000 - loss: 0.0028 - val_accuracy: 0.7969 - val_loss: 0.6556
# Epoch 20/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 0.7816 - val_loss: 0.6647
# RandomSearch duration: 520.48 seconds
#
# Best parameters found:
# {'optimizer__learning_rate': 0.005, 'model__hidden_layer_2_neurons': 0, 'model__hidden_layer_1_neurons': 256, 'model__dropout_rate': 0.2, 'model__activation': 'relu'}
#
# Best CV score:
# 0.8070556304443345
# Best CV f1 for Custom_MLP on Scaled_RFE75%: 0.8071
#
# Evaluating Custom_MLP on the test set using Scaled_RFE75%...
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Prediction duration: 0.1578 seconds
# Accuracy: 0.7791
# Precision: 0.7651
# Recall (Sensitivity): 0.7937
# F1 Score: 0.7791
#
# Confusion Matrix (Custom_MLP on Scaled_RFE75%):
# [[127  39]
#  [ 33 127]]
#
# --- Tuning Custom_MLP on Feature Set: Scaled_RFE50% (4263 features) ---
#
# Performing RandomSearch tuning (scoring='f1')...
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Epoch 1/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.5788 - loss: 0.8125 - val_accuracy: 0.7318 - val_loss: 0.5457
# Epoch 2/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7487 - loss: 0.5213 - val_accuracy: 0.7701 - val_loss: 0.5080
# Epoch 3/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8011 - loss: 0.4289 - val_accuracy: 0.8046 - val_loss: 0.4213
# Epoch 4/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8559 - loss: 0.3150 - val_accuracy: 0.8123 - val_loss: 0.3684
# Epoch 5/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9153 - loss: 0.2530 - val_accuracy: 0.8314 - val_loss: 0.3401
# Epoch 6/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9273 - loss: 0.1862 - val_accuracy: 0.8467 - val_loss: 0.3209
# Epoch 7/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9495 - loss: 0.1510 - val_accuracy: 0.8352 - val_loss: 0.3087
# Epoch 8/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9516 - loss: 0.1480 - val_accuracy: 0.8582 - val_loss: 0.3030
# Epoch 9/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9745 - loss: 0.0909 - val_accuracy: 0.8736 - val_loss: 0.2885
# Epoch 10/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9773 - loss: 0.0883 - val_accuracy: 0.8966 - val_loss: 0.2858
# Epoch 11/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9827 - loss: 0.0659 - val_accuracy: 0.8889 - val_loss: 0.2919
# Epoch 12/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9904 - loss: 0.0660 - val_accuracy: 0.8697 - val_loss: 0.2940
# Epoch 13/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9747 - loss: 0.0685 - val_accuracy: 0.8621 - val_loss: 0.3285
# Epoch 14/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9895 - loss: 0.0439 - val_accuracy: 0.8736 - val_loss: 0.2932
# Epoch 15/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9822 - loss: 0.0466 - val_accuracy: 0.8812 - val_loss: 0.3006
# Epoch 16/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9883 - loss: 0.0480 - val_accuracy: 0.8774 - val_loss: 0.2805
# Epoch 17/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9944 - loss: 0.0447 - val_accuracy: 0.8851 - val_loss: 0.2886
# Epoch 18/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9968 - loss: 0.0316 - val_accuracy: 0.8851 - val_loss: 0.3165
# Epoch 19/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9954 - loss: 0.0410 - val_accuracy: 0.8774 - val_loss: 0.3088
# Epoch 20/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9941 - loss: 0.0293 - val_accuracy: 0.8927 - val_loss: 0.3251
# Epoch 21/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9962 - loss: 0.0253 - val_accuracy: 0.8774 - val_loss: 0.3178
# Epoch 22/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9883 - loss: 0.0354 - val_accuracy: 0.8774 - val_loss: 0.3195
# Epoch 23/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9917 - loss: 0.0283 - val_accuracy: 0.8736 - val_loss: 0.3297
# Epoch 24/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9907 - loss: 0.0349 - val_accuracy: 0.8966 - val_loss: 0.3380
# Epoch 25/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9949 - loss: 0.0183 - val_accuracy: 0.8812 - val_loss: 0.3264
# Epoch 26/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9952 - loss: 0.0214 - val_accuracy: 0.8966 - val_loss: 0.3240
# Epoch 27/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9946 - loss: 0.0220 - val_accuracy: 0.8812 - val_loss: 0.3032
# Epoch 28/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9900 - loss: 0.0299 - val_accuracy: 0.8851 - val_loss: 0.3230
# Epoch 29/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9930 - loss: 0.0312 - val_accuracy: 0.8889 - val_loss: 0.3041
# Epoch 30/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9844 - loss: 0.0459 - val_accuracy: 0.8851 - val_loss: 0.2905
# Epoch 31/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9964 - loss: 0.0222 - val_accuracy: 0.8889 - val_loss: 0.2823
# RandomSearch duration: 532.00 seconds
#
# Best parameters found:
# {'optimizer__learning_rate': 0.01, 'model__hidden_layer_2_neurons': 64, 'model__hidden_layer_1_neurons': 256, 'model__dropout_rate': 0.6, 'model__activation': 'leaky_relu'}
#
# Best CV score:
# 0.871005422544686
# Best CV f1 for Custom_MLP on Scaled_RFE50%: 0.8710
#
# Evaluating Custom_MLP on the test set using Scaled_RFE50%...
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# Prediction duration: 0.1874 seconds
# Accuracy: 0.7546
# Precision: 0.7247
# Recall (Sensitivity): 0.8063
# F1 Score: 0.7633
#
# Confusion Matrix (Custom_MLP on Scaled_RFE50%):
# [[117  49]
#  [ 31 129]]
#
# --- Tuning Custom_MLP on Feature Set: Scaled_PCA_95% (814 features) ---
#
# Performing RandomSearch tuning (scoring='f1')...
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Epoch 1/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5914 - loss: 0.7135 - val_accuracy: 0.6782 - val_loss: 0.6486
# Epoch 2/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9001 - loss: 0.3119 - val_accuracy: 0.7203 - val_loss: 0.5747
# Epoch 3/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9794 - loss: 0.1604 - val_accuracy: 0.7280 - val_loss: 0.5725
# Epoch 4/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9930 - loss: 0.0952 - val_accuracy: 0.7126 - val_loss: 0.5793
# Epoch 5/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9901 - loss: 0.0703 - val_accuracy: 0.7318 - val_loss: 0.5925
# Epoch 6/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9950 - loss: 0.0607 - val_accuracy: 0.7356 - val_loss: 0.6250
# Epoch 7/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9985 - loss: 0.0397 - val_accuracy: 0.7548 - val_loss: 0.6338
# Epoch 8/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9968 - loss: 0.0299 - val_accuracy: 0.7356 - val_loss: 0.6546
# Epoch 9/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9992 - loss: 0.0192 - val_accuracy: 0.7356 - val_loss: 0.6770
# Epoch 10/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9995 - loss: 0.0161 - val_accuracy: 0.7280 - val_loss: 0.6916
# Epoch 11/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9983 - loss: 0.0178 - val_accuracy: 0.7280 - val_loss: 0.7080
# Epoch 12/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9996 - loss: 0.0125 - val_accuracy: 0.7203 - val_loss: 0.7269
# Epoch 13/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9971 - loss: 0.0146 - val_accuracy: 0.7126 - val_loss: 0.7371
# Epoch 14/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9999 - loss: 0.0133 - val_accuracy: 0.7126 - val_loss: 0.7556
# Epoch 15/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9997 - loss: 0.0091 - val_accuracy: 0.7088 - val_loss: 0.7819
# Epoch 16/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9998 - loss: 0.0065 - val_accuracy: 0.7088 - val_loss: 0.7948
# Epoch 17/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0053 - val_accuracy: 0.7126 - val_loss: 0.8094
# Epoch 18/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0058 - val_accuracy: 0.7203 - val_loss: 0.8241
# RandomSearch duration: 173.80 seconds
#
# Best parameters found:
# {'optimizer__learning_rate': 0.005, 'model__hidden_layer_2_neurons': 0, 'model__hidden_layer_1_neurons': 256, 'model__dropout_rate': 0.2, 'model__activation': 'relu'}
#
# Best CV score:
# 0.7461162818330822
# Best CV f1 for Custom_MLP on Scaled_PCA_95%: 0.7461
#
# Evaluating Custom_MLP on the test set using Scaled_PCA_95%...
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Prediction duration: 0.1360 seconds
# Accuracy: 0.8067
# Precision: 0.7771
# Recall (Sensitivity): 0.8500
# F1 Score: 0.8119
#
# Confusion Matrix (Custom_MLP on Scaled_PCA_95%):
# [[127  39]
#  [ 24 136]]
#
# --- Tuning Custom_MLP on Feature Set: Scaled_PCA_1000 (1000 features) ---
#
# Performing RandomSearch tuning (scoring='f1')...
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Epoch 1/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.5033 - loss: 0.9347 - val_accuracy: 0.5939 - val_loss: 0.6697
# Epoch 2/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5700 - loss: 0.7433 - val_accuracy: 0.6360 - val_loss: 0.6132
# Epoch 3/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6014 - loss: 0.6822 - val_accuracy: 0.6820 - val_loss: 0.5864
# Epoch 4/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6761 - loss: 0.5837 - val_accuracy: 0.6973 - val_loss: 0.5712
# Epoch 5/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7243 - loss: 0.5232 - val_accuracy: 0.7241 - val_loss: 0.5451
# Epoch 6/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7476 - loss: 0.5084 - val_accuracy: 0.7433 - val_loss: 0.5310
# Epoch 7/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8209 - loss: 0.4268 - val_accuracy: 0.7318 - val_loss: 0.5208
# Epoch 8/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8347 - loss: 0.3597 - val_accuracy: 0.7395 - val_loss: 0.5123
# Epoch 9/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8721 - loss: 0.3088 - val_accuracy: 0.7395 - val_loss: 0.5095
# Epoch 10/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9009 - loss: 0.2624 - val_accuracy: 0.7356 - val_loss: 0.5081
# Epoch 11/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8924 - loss: 0.2548 - val_accuracy: 0.7433 - val_loss: 0.5090
# Epoch 12/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9236 - loss: 0.2008 - val_accuracy: 0.7471 - val_loss: 0.5137
# Epoch 13/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9463 - loss: 0.1721 - val_accuracy: 0.7471 - val_loss: 0.5230
# Epoch 14/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9693 - loss: 0.1392 - val_accuracy: 0.7395 - val_loss: 0.5322
# Epoch 15/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9571 - loss: 0.1407 - val_accuracy: 0.7395 - val_loss: 0.5386
# Epoch 16/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9690 - loss: 0.1300 - val_accuracy: 0.7356 - val_loss: 0.5528
# Epoch 17/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9694 - loss: 0.1035 - val_accuracy: 0.7433 - val_loss: 0.5689
# Epoch 18/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9812 - loss: 0.0857 - val_accuracy: 0.7433 - val_loss: 0.5762
# Epoch 19/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9751 - loss: 0.0853 - val_accuracy: 0.7318 - val_loss: 0.5951
# Epoch 20/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9825 - loss: 0.0821 - val_accuracy: 0.7280 - val_loss: 0.6149
# Epoch 21/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9830 - loss: 0.0719 - val_accuracy: 0.7203 - val_loss: 0.6239
# Epoch 22/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9861 - loss: 0.0618 - val_accuracy: 0.7280 - val_loss: 0.6390
# Epoch 23/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9844 - loss: 0.0689 - val_accuracy: 0.7280 - val_loss: 0.6502
# Epoch 24/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9910 - loss: 0.0600 - val_accuracy: 0.7280 - val_loss: 0.6722
# Epoch 25/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9877 - loss: 0.0519 - val_accuracy: 0.7280 - val_loss: 0.6904
# RandomSearch duration: 178.15 seconds
#
# Best parameters found:
# {'optimizer__learning_rate': 0.001, 'model__hidden_layer_2_neurons': 64, 'model__hidden_layer_1_neurons': 128, 'model__dropout_rate': 0.6, 'model__activation': 'relu'}
#
# Best CV score:
# 0.7288297453239961
# Best CV f1 for Custom_MLP on Scaled_PCA_1000: 0.7288
#
# Evaluating Custom_MLP on the test set using Scaled_PCA_1000...
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Prediction duration: 0.1857 seconds
# Accuracy: 0.7945
# Precision: 0.7688
# Recall (Sensitivity): 0.8313
# F1 Score: 0.7988
#
# Confusion Matrix (Custom_MLP on Scaled_PCA_1000):
# [[126  40]
#  [ 27 133]]
#
# --- Model Training and Hyperparameter Tuning Complete ---

# %%
print("\n\n=== Results Summary Across Models and Feature Sets ===")

if 'all_results' not in locals() or not all_results:
    print("No results available to summarize.")
else:
    print("\nCross-Validation Results (Best CV F1 Score):")
    print("-------------------------------------------------")
    for model_name, fs_results in all_results.items():
        print(f"\n{model_name}:")
        if fs_results:
            for fs_name, result in fs_results.items():
                 cv_score = result.get('best_cv_score', float('nan'))
                 print(f"  - {fs_name}: {cv_score:.4f}")
        else:
            print("  No results for this model.")
     
    print("\nTest Set Results (F1 Score):")
    print("----------------------------")
    for model_name, fs_results in all_results.items():
        print(f"\n{model_name}:")
        if fs_results:
            for fs_name, result in fs_results.items():
                 test_f1 = result.get('test_metrics', {}).get('f1_score', float('nan'))
                 print(f"  - {fs_name}: {test_f1:.4f}")
        else:
            print("  No test results for this model.")
            
    print("\n=== Overall Best Combination on Test Set (Based on F1 Score) ===")
    if best_overall_combination:
        model_name, fs_name = best_overall_combination
        best_result = all_results[model_name][fs_name]
        test_metrics = best_result['test_metrics']
        print(f"Best Model: {model_name}")
        print(f"Best Feature Set: {fs_name} ({feature_sets[fs_name][0].shape[1]} features)")
        print(f"Best CV F1 Score: {best_result['best_cv_score']:.4f}")
        print(f"Test F1 Score: {test_metrics['f1_score']:.4f}")
        print(f"Test Accuracy: {test_metrics['accuracy']:.4f}")
        print(f"Test Precision: {test_metrics['precision']:.4f}")
        print(f"Test Recall: {test_metrics['recall']:.4f}")
        print(f"Best Parameters: {best_result['best_params']}")
        print(f"Confusion Matrix:\n{np.array(test_metrics['confusion_matrix'])}")
    else:
        print("No successful model tuning and evaluation completed to determine the best combination.")
# Out:
# === Results Summary Across Models and Feature Sets ===
#
# Cross-Validation Results (Best CV F1 Score):
# -------------------------------------------------
#
# SVM:
#   - Scaled_All: 0.7853
#   - Scaled_Corr75%: 0.7823
#   - Scaled_Corr50%: 0.7860
#   - Scaled_RFE75%: 0.8100
#   - Scaled_RFE50%: 0.8995
#   - Scaled_PCA_95%: 0.7873
#   - Scaled_PCA_1000: 0.7883
#
# LightGBM:
#   - Scaled_All: 0.7572
#   - Scaled_Corr75%: 0.7549
#   - Scaled_Corr50%: 0.7734
#   - Scaled_RFE75%: 0.7610
#   - Scaled_RFE50%: 0.7762
#   - Scaled_PCA_95%: 0.7102
#   - Scaled_PCA_1000: 0.7251
#
# Custom_MLP:
#   - Scaled_All: 0.7587
#   - Scaled_Corr75%: 0.7558
#   - Scaled_Corr50%: 0.7457
#   - Scaled_RFE75%: 0.8071
#   - Scaled_RFE50%: 0.8710
#   - Scaled_PCA_95%: 0.7461
#   - Scaled_PCA_1000: 0.7288
#
# Test Set Results (F1 Score):
# ----------------------------
#
# SVM:
#   - Scaled_All: 0.8378
#   - Scaled_Corr75%: 0.8323
#   - Scaled_Corr50%: 0.8278
#   - Scaled_RFE75%: 0.8393
#   - Scaled_RFE50%: 0.7405
#   - Scaled_PCA_95%: 0.8309
#   - Scaled_PCA_1000: 0.8402
#
# LightGBM:
#   - Scaled_All: 0.7906
#   - Scaled_Corr75%: 0.7975
#   - Scaled_Corr50%: 0.8179
#   - Scaled_RFE75%: 0.8024
#   - Scaled_RFE50%: 0.7988
#   - Scaled_PCA_95%: 0.7703
#   - Scaled_PCA_1000: 0.7235
#
# Custom_MLP:
#   - Scaled_All: 0.7596
#   - Scaled_Corr75%: 0.7673
#   - Scaled_Corr50%: 0.7611
#   - Scaled_RFE75%: 0.7791
#   - Scaled_RFE50%: 0.7633
#   - Scaled_PCA_95%: 0.8119
#   - Scaled_PCA_1000: 0.7988
#
# === Overall Best Combination on Test Set (Based on F1 Score) ===
# Best Model: SVM
# Best Feature Set: Scaled_PCA_1000 (1000 features)
# Best CV F1 Score: 0.7883
# Test F1 Score: 0.8402
# Test Accuracy: 0.8344
# Test Precision: 0.7978
# Test Recall: 0.8875
# Best Parameters: {'kernel': 'rbf', 'gamma': 'scale', 'C': 10}
# Confusion Matrix:
# [[130  36]
#  [ 18 142]]

# %%
MODEL_SAVE_DIR = os.path.join('..', 'models')
os.makedirs(MODEL_SAVE_DIR, exist_ok=True)
print("\n--- Saving Best Model Per Algorithm (Based on Test F1) ---")
if 'best_f1_per_model' not in locals() or not best_result:
     print("Could not determine best feature set per model. ??")
else:
    for model_name, (best_fs_name_for_model, best_test_f1_for_model) in best_result.items():
        print(f"\nProcessing {model_name}...")
        if best_fs_name_for_model and model_name in all_results and best_fs_name_for_model in all_results[model_name]:
            best_combination_results = all_results[model_name][best_fs_name_for_model]
            model_to_save = best_combination_results.get('trained_model')
            transformer_to_save = best_combination_results.get('transformer')

            if model_to_save:
                is_keras_model = isinstance(model_to_save, KerasClassifier)
                file_extension = '.keras' if is_keras_model else '.pkl'
                model_filename = f'Kaggle_{model_name.lower()}_best_model_{best_fs_name_for_model}{file_extension}'
                MODEL_SAVE_PATH_ALG = os.path.join(MODEL_SAVE_DIR, model_filename)

                try:
                    if is_keras_model:
                        model_to_save.model_.save(MODEL_SAVE_PATH_ALG)
                    else:
                        joblib.dump(model_to_save, MODEL_SAVE_PATH_ALG)
                    print(f"   Saved model: {MODEL_SAVE_PATH_ALG}")
                except Exception as e:
                    print(f"   Error saving {model_name} model to {MODEL_SAVE_PATH_ALG}: {e}")
            else:
                print(f"   No trained model found for {model_name} on {best_fs_name_for_model}.")
            if transformer_to_save and best_fs_name_for_model != 'Scaled_All':
                 transformer_filename = f'Kaggle_selector_{best_fs_name_for_model}.pkl'
                 TRANSFORMER_SAVE_PATH = os.path.join(MODEL_SAVE_DIR, transformer_filename)
                 try:
                     joblib.dump(transformer_to_save, TRANSFORMER_SAVE_PATH)
                     print(f"   Saved feature selection transformer: {TRANSFORMER_SAVE_PATH}")
                 except Exception as e:
                    print(f"   Error saving transformer for {best_fs_name_for_model} to {TRANSFORMER_SAVE_PATH}: {e}")
            elif best_fs_name_for_model != 'Scaled_All':
                print(f"   Warning: Feature selection transformer not found for {best_fs_name_for_model}.")
        else:
            print(f"No valid results found for the best feature set '{best_fs_name_for_model}' for model {model_name}.")

print("\n--- Saving Process Complete ---")
# Out:
# --- Saving Best Model Per Algorithm (Based on Test F1) ---
# Could not determine best feature set per model. ??
#
# --- Saving Process Complete ---
